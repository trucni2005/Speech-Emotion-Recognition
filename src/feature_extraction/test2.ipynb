# %%
from loguru import logger
import os
import librosa
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
from scripts.mfcc_extractor import MfccExtractor
from scripts.pitch_extractor import PitchExtractor
from scripts.rms_extractor import RmsExtractor
from scripts.zcr_extractor import ZcrExtractor
import pandas as pd
import concurrent.futures
import logging

class StatisticFeatureExtraction:
    def __init__(self, n_mfcc=20):
        self.n_mfcc = n_mfcc

    def extract_mfcc_statistics(self, signal, sample_rate):
        mfcc_extractor = MfccExtractor(signal, sample_rate, self.n_mfcc)
        features = mfcc_extractor.compute_mfccs_statistics()
        feature_data = {}
        for i, (mean, var, max_val, min_val, median, p25, p75, rng, skewness, kurt, energy) in enumerate(zip(
                features['mfcc_mean'],
                features['mfcc_variance'],
                features['mfcc_max'],
                features['mfcc_min'],
                features['mfcc_median'],
                features['mfcc_25th_percentile'],
                features['mfcc_75th_percentile'],
                features['mfcc_range'],
                features['mfcc_skewness'],
                features['mfcc_kurtosis'],
                features['mfcc_energy'])):
            feature_data[f'mfcc_mean_{i+1}'] = mean
            feature_data[f'mfcc_variance_{i+1}'] = var
            feature_data[f'mfcc_max_{i+1}'] = max_val
            feature_data[f'mfcc_min_{i+1}'] = min_val
            feature_data[f'mfcc_median_{i+1}'] = median
            feature_data[f'mfcc_25th_percentile_{i+1}'] = p25
            feature_data[f'mfcc_75th_percentile_{i+1}'] = p75
            feature_data[f'mfcc_range_{i+1}'] = rng
            feature_data[f'mfcc_skewness_{i+1}'] = skewness
            feature_data[f'mfcc_kurtosis_{i+1}'] = kurt
            feature_data[f'mfcc_energy_{i+1}'] = energy

        return feature_data

    def extract_pitch_statistics(self, signal, sample_rate):
        pitch_extractor = PitchExtractor(signal, sample_rate)
        return pitch_extractor.compute_pitch_statistics()

    def extract_zcr_statistics(self, signal, frame_size, hop_size):
        zcr_extractor = ZcrExtractor(signal, frame_size, hop_size)
        return zcr_extractor.compute_zcr_statistics()

    def extract_rms_statistics(self, signal, frame_size, hop_size):
        rms_extractor = RmsExtractor(signal, frame_size, hop_size)
        return rms_extractor.compute_rms_statistics()

    def feature_engineering_for_file(self, audio_file, target_seconds=180):
        try:
            signal, sample_rate = librosa.load(audio_file, sr=None)
            if len(signal) >= 2048:
                features = {}
                
                # MFCC features
                mfcc_stats = self.extract_mfcc_statistics(signal, sample_rate)
                features.update({f'{key}': value for key, value in mfcc_stats.items()})

                # ZCR features
                zcr_stats = self.extract_zcr_statistics(signal, frame_size=2048, hop_size=512)
                features.update({f'zcr_{key}': value for key, value in zcr_stats.items()})

                # Pitch features
                pitch_stats = self.extract_pitch_statistics(signal, sample_rate)
                features.update({f'pitch_{key}': value for key, value in pitch_stats.items()})

                # RMS features
                rms_stats = self.extract_rms_statistics(signal, frame_size=2048, hop_size=512)
                features.update({f'rms_{key}': value for key, value in rms_stats.items()})

                return features
            
        except Exception as e:
            logger.error(f"Error processing file {audio_file}: {e}")
        return None

    def process_folder(self, input_folder, csv_file):
      file_and_label_df = pd.read_excel(csv_file)
      feature_dataframes = pd.DataFrame()  # DataFrame để lưu trữ các features từ tất cả các file âm thanh

      for index, row in file_and_label_df.iterrows():
          file_path = row['cleaned_file_path']
          label = row['label']
          features = self.feature_engineering_for_file(file_path)

          if index % 100 == 0:
              logger.info(f'Processed {index} file!')
              feature_dataframes.to_csv('train_add_feature_data.csv', index=False)

          if features is not None:
              features['file_path'] = file_path
              features['label'] = label
              feature_dataframe = pd.DataFrame([features])  # Tạo DataFrame từ features của mỗi file
              feature_dataframes = pd.concat([feature_dataframes, feature_dataframe], ignore_index=True)  # Kết hợp DataFrame mới vào DataFrame tổng hợp

      # Lưu DataFrame tổng hợp vào tệp CSV
      feature_dataframes.to_csv('train_add_feature_data.csv', index=False)


feature_extractor = StatisticFeatureExtraction()
feature_extractor.process_folder(r'D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train', r"D:\data_analysis\speech_emotion_recognition\src\feature_extraction\Book1.xlsx")
# Out:
# 2024-05-30 05:45:41.299 | INFO     | __main__:process_folder:99 - Processed 0 file!
# 2024-05-30 05:46:47.085 | INFO     | __main__:process_folder:99 - Processed 100 file!
# 2024-05-30 05:46:48.897 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\1027_IEO_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:46:49.549 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_1027_IEO_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:47:47.408 | INFO     | __main__:process_folder:99 - Processed 200 file!
# 2024-05-30 05:48:44.729 | INFO     | __main__:process_folder:99 - Processed 300 file!
# 2024-05-30 05:49:16.823 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\1035_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:49:17.613 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_1035_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:49:18.409 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\time_shift_1035_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:49:44.929 | INFO     | __main__:process_folder:99 - Processed 400 file!
# 2024-05-30 05:49:55.539 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\1038_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:49:56.074 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_1038_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:50:28.438 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\1040_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:50:29.012 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_1040_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:50:29.563 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\time_shift_1040_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:50:46.739 | INFO     | __main__:process_folder:99 - Processed 500 file!
# 2024-05-30 05:51:44.535 | INFO     | __main__:process_folder:99 - Processed 600 file!
# 2024-05-30 05:52:44.794 | INFO     | __main__:process_folder:99 - Processed 700 file!
# 2024-05-30 05:53:40.592 | INFO     | __main__:process_folder:99 - Processed 800 file!
# 2024-05-30 05:54:00.673 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\time_shift_1051_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:54:40.988 | INFO     | __main__:process_folder:99 - Processed 900 file!
# 2024-05-30 05:55:38.398 | INFO     | __main__:process_folder:99 - Processed 1000 file!
# 2024-05-30 05:56:44.298 | INFO     | __main__:process_folder:99 - Processed 1100 file!
# 2024-05-30 05:57:41.376 | INFO     | __main__:process_folder:99 - Processed 1200 file!
# 2024-05-30 05:57:43.540 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\time_shift_1065_ITH_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:57:51.432 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\1065_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:57:51.924 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_1065_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:57:52.439 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\time_shift_1065_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:57:54.951 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\1066_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:57:55.378 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_1066_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 05:58:39.795 | INFO     | __main__:process_folder:99 - Processed 1300 file!
# 2024-05-30 05:59:39.838 | INFO     | __main__:process_folder:99 - Processed 1400 file!
# 2024-05-30 06:00:24.428 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\time_shift_1075_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 06
:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\train\noisy_03-01-08-02-02-02-21.wav: 'tuple' object has no attribute 'items'
# 2024-05-30 07:14:49.340 | INFO     | __main__:process_folder:99 - Processed 8000 file!
# 2024-05-30 07:15:50.546 | INFO     | __main__:process_folder:99 - Processed 8100 file!
# 2024-05-30 07:16:52.651 | INFO     | __main__:process_folder:99 - Processed 8200 file!
# 2024-05-30 07:17:53.405 | INFO     | __main__:process_folder:99 - Processed 8300 file!
# 2024-05-30 07:18:55.287 | INFO     | __main__:process_folder:99 - Processed 8400 file!
# 2024-05-30 07:19:59.486 | INFO     | __main__:process_folder:99 - Processed 8500 file!
# 2024-05-30 07:20:58.640 | INFO     | __main__:process_folder:99 - Processed 8600 file!
# 2024-05-30 07:21:59.021 | INFO     | __main__:process_folder:99 - Processed 8700 file!
# 2024-05-30 07:22:56.950 | INFO     | __main__:process_folder:99 - Processed 8800 file!
# 2024-05-30 07:23:58.276 | INFO     | __main__:process_folder:99 - Processed 8900 file!

# %%
import pandas as pd

# Load the CSV files
train_feature_data = pd.read_csv('train_feature_data.csv')
train_add_feature_data = pd.read_csv('train_add_feature_data.csv')

# Concatenate the DataFrames
merged_data = pd.concat([train_feature_data, train_add_feature_data])

# Save the merged DataFrame to a new CSV file
merged_data.to_csv('merged_train_feature_data.csv', index=False)

# %%
from loguru import logger
import os
import librosa
import csv
import pandas as pd
import numpy as np
from scripts.mfcc_extractor import MfccExtractor
from scripts.pitch_extractor import PitchExtractor
from scripts.rms_extractor import RmsExtractor
from scripts.zcr_extractor import ZcrExtractor

class FeatureExtractor:
    def __init__(self, n_mfcc=20):
        self.n_mfcc = n_mfcc

    def extract_original_mfcc(self, signal, sample_rate, frame_size, hop_size):
        mfcc_extractor = MfccExtractor(signal, sample_rate, self.n_mfcc, frame_size, hop_size)
        mfcc_matrix = mfcc_extractor.compute_mfccs()
        mfcc_vectors = []
        for row in range(mfcc_matrix.shape[0]):
            mfcc_vector = mfcc_matrix[row, :]
            mfcc_vectors.append(mfcc_vector)

        return mfcc_vectors
    
    def extract_pitch(self, signal, sample_rate, frame_size, hop_size):
        pitch_extractor = PitchExtractor(signal, sample_rate, frame_size, hop_size)
        return pitch_extractor.compute_pitch()
    
    def extract_original_zcr(self, signal, frame_size, hop_size):
        zcr_extractor = ZcrExtractor(signal, frame_size, hop_size)
        zcr = zcr_extractor.compute_zcr()
        return zcr
    
    def extract_original_rms(self, signal, frame_size, hop_size):
        rms_extractor = RmsExtractor(signal, frame_size, hop_size)
        return rms_extractor.compute_rms()
    
    def pad_or_trim(self, zcr, target_length):
      if len(zcr) < target_length:
          return np.pad(zcr, (0, target_length - len(zcr)), 'constant')
      else:
          return zcr[:target_length]
    
    def calculate_number_of_frames(self, audio_length, sample_rate, frame_length, hop_length):
      """
      Tính số lượng khung dựa vào độ dài tín hiệu âm thanh, tần số lấy mẫu, frame length, và hop length.
      """
      # Tính độ dài tín hiệu âm thanh bằng số mẫu
      signal_length = int(audio_length * sample_rate)
      
      # Tính số lượng khung
      num_frames = 1 + (signal_length - frame_length) // hop_length
      
      return num_frames

    def feature_engineering_for_file(self, audio_file, target_seconds=3, frame_size=2048, hop_size=512):
        try:
            signal, sample_rate = librosa.load(audio_file, sr=None)
            if len(signal) >= frame_size:
                zcr = self.extract_original_zcr(signal, frame_size, hop_size)
                num_of_frames = self.calculate_number_of_frames(target_seconds, sample_rate, frame_size, hop_size)
                zcr_normalize = self.pad_or_trim(zcr, num_of_frames)

                rms = self.extract_original_rms(signal, frame_size, hop_size)
                rms_normalize = self.pad_or_trim(rms, num_of_frames)

                pitch = self.extract_pitch(signal, sample_rate, frame_size, hop_size)
                pitch_normalize = self.pad_or_trim(pitch, num_of_frames)

                mfcc_normalize = []
                for mfcc_vector in self.extract_original_mfcc(signal, sample_rate, frame_size, hop_size):
                    normalized_mfcc_vector = self.pad_or_trim(mfcc_vector, num_of_frames)
                    mfcc_normalize.append(normalized_mfcc_vector)
                
                stacked_mfcc = np.hstack(mfcc_normalize)

                combined_features = np.hstack((zcr_normalize, rms_normalize, pitch_normalize, stacked_mfcc))
                return combined_features
        except Exception as e:
            logger.error(f"Error processing file {audio_file}: {e}")
        return None

    def process_folder(self, input_folder, csv_file):
        file_and_label_df = pd.read_csv(csv_file)
        feature_dataframes = pd.DataFrame()  # DataFrame to store features from all audio files

        for index, row in file_and_label_df.iterrows():
            file_path = row['cleaned_file_path']
            label = row['label']
            features = self.feature_engineering_for_file(file_path)

            if index % 100 == 0:
                logger.info(f'Processed {index} file!')
                feature_dataframes.to_csv('_test_feature_data.csv', index=False)

            if features is not None:
                features_dict = {
                    'file_path': file_path,
                    'label': label
                }
                for i, feature in enumerate(features):
                    features_dict[f'feature_{i+1}'] = feature  # Assign feature values to corresponding columns in DataFrame
                feature_dataframe = pd.DataFrame([features_dict])  # Convert the dictionary to a DataFrame
                feature_dataframes = pd.concat([feature_dataframes, feature_dataframe], ignore_index=True)  # Append the new row to the aggregated DataFrame

        # Save the aggregated DataFrame to a CSV file
        feature_dataframes.to_csv('_test_feature_data.csv', index=False)

# %%
feature_extractor = FeatureExtractor()
feature_extractor.process_folder(r'D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\test', r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\test_file_paths_with_labels.csv")
# Out:
# 2024-05-31 08:10:02.204 | INFO     | __main__:process_folder:94 - Processed 0 file!
# 2024-05-31 08:10:49.978 | INFO     | __main__:process_folder:94 - Processed 100 file!
# 2024-05-31 08:11:39.360 | INFO     | __main__:process_folder:94 - Processed 200 file!
# 2024-05-31 08:12:24.938 | INFO     | __main__:process_folder:94 - Processed 300 file!
# 2024-05-31 08:13:10.079 | INFO     | __main__:process_folder:94 - Processed 400 file!
# 2024-05-31 08:13:51.495 | INFO     | __main__:process_folder:94 - Processed 500 file!
# 2024-05-31 08:14:40.433 | INFO     | __main__:process_folder:94 - Processed 600 file!
# 2024-05-31 08:15:47.909 | INFO     | __main__:process_folder:94 - Processed 700 file!
# 2024-05-31 08:16:44.278 | INFO     | __main__:process_folder:94 - Processed 800 file!
# 2024-05-31 08:17:42.426 | INFO     | __main__:process_folder:94 - Processed 900 file!
# 2024-05-31 08:18:45.817 | INFO     | __main__:process_folder:94 - Processed 1000 file!
# 2024-05-31 08:20:14.308 | INFO     | __main__:process_folder:94 - Processed 1100 file!
# 2024-05-31 08:21:23.977 | INFO     | __main__:process_folder:94 - Processed 1200 file!
# 2024-05-31 08:22:33.367 | INFO     | __main__:process_folder:94 - Processed 1300 file!
# 2024-05-31 08:23:34.934 | INFO     | __main__:process_folder:94 - Processed 1400 file!
# 2024-05-31 08:24:30.924 | INFO     | __main__:process_folder:94 - Processed 1500 file!
# 2024-05-31 08:25:39.567 | INFO     | __main__:process_folder:94 - Processed 1600 file!
# 2024-05-31 08:26:43.179 | INFO     | __main__:process_folder:94 - Processed 1700 file!
# 2024-05-31 08:27:53.683 | INFO     | __main__:process_folder:94 - Processed 1800 file!
# 2024-05-31 08:29:09.832 | INFO     | __main__:process_folder:94 - Processed 1900 file!
# 2024-05-31 08:30:26.285 | INFO     | __main__:process_folder:94 - Processed 2000 file!
# 2024-05-31 08:31:42.695 | INFO     | __main__:process_folder:94 - Processed 2100 file!
# 2024-05-31 08:32:47.077 | INFO     | __main__:process_folder:94 - Processed 2200 file!
# 2024-05-31 08:34:03.302 | INFO     | __main__:process_folder:94 - Processed 2300 file!
# 2024-05-31 08:35:08.615 | INFO     | __main__:process_folder:94 - Processed 2400 file!
# 2024-05-31 08:36:20.135 | INFO     | __main__:process_folder:94 - Processed 2500 file!
# 2024-05-31 08:37:21.018 | INFO     | __main__:process_folder:94 - Processed 2600 file!
# 2024-05-31 08:38:21.417 | INFO     | __main__:process_folder:94 - Processed 2700 file!
# 2024-05-31 08:39:22.186 | INFO     | __main__:process_folder:94 - Processed 2800 file!
# 2024-05-31 08:40:58.162 | INFO     | __main__:process_folder:94 - Processed 2900 file!
# 2024-05-31 08:42:17.127 | INFO     | __main__:process_folder:94 - Processed 3000 file!
# 2024-05-31 08:43:28.122 | INFO     | __main__:process_folder:94 - Processed 3100 file!
# 2024-05-31 08:44:46.451 | INFO     | __main__:process_folder:94 - Processed 3200 file!
# 2024-05-31 08:45:54.960 | INFO     | __main__:process_folder:94 - Processed 3300 file!
# 2024-05-31 08:47:04.378 | INFO     | __main__:process_folder:94 - Processed 3400 file!
