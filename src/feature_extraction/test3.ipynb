# %%
from loguru import logger
import os
import librosa
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis
from scripts.mfcc_extractor import MfccExtractor
from scripts.pitch_extractor import PitchExtractor
from scripts.rms_extractor import RmsExtractor
from scripts.zcr_extractor import ZcrExtractor
import pandas as pd
import concurrent.futures
import logging

class StatisticFeatureExtraction:
    def __init__(self, n_mfcc=20):
        self.n_mfcc = n_mfcc

    def extract_mfcc_statistics(self, signal, sample_rate):
        mfcc_extractor = MfccExtractor(signal, sample_rate, self.n_mfcc)
        features = mfcc_extractor.compute_mfccs_statistics()
        feature_data = {}
        for i, (mean, var, max_val, min_val, median, p25, p75, rng, skewness, kurt, energy) in enumerate(zip(
                features['mfcc_mean'],
                features['mfcc_variance'],
                features['mfcc_max'],
                features['mfcc_min'],
                features['mfcc_median'],
                features['mfcc_25th_percentile'],
                features['mfcc_75th_percentile'],
                features['mfcc_range'],
                features['mfcc_skewness'],
                features['mfcc_kurtosis'],
                features['mfcc_energy'])):
            feature_data[f'mfcc_mean_{i+1}'] = mean
            feature_data[f'mfcc_variance_{i+1}'] = var
            feature_data[f'mfcc_max_{i+1}'] = max_val
            feature_data[f'mfcc_min_{i+1}'] = min_val
            feature_data[f'mfcc_median_{i+1}'] = median
            feature_data[f'mfcc_25th_percentile_{i+1}'] = p25
            feature_data[f'mfcc_75th_percentile_{i+1}'] = p75
            feature_data[f'mfcc_range_{i+1}'] = rng
            feature_data[f'mfcc_skewness_{i+1}'] = skewness
            feature_data[f'mfcc_kurtosis_{i+1}'] = kurt
            feature_data[f'mfcc_energy_{i+1}'] = energy

        return feature_data

    def extract_pitch_statistics(self, signal, sample_rate):
        pitch_extractor = PitchExtractor(signal, sample_rate)
        return pitch_extractor.compute_pitch_statistics()

    def extract_zcr_statistics(self, signal, frame_size, hop_size):
        zcr_extractor = ZcrExtractor(signal, frame_size, hop_size)
        return zcr_extractor.compute_zcr_statistics()

    def extract_rms_statistics(self, signal, frame_size, hop_size):
        rms_extractor = RmsExtractor(signal, frame_size, hop_size)
        return rms_extractor.compute_rms_statistics()

    def feature_engineering_for_file(self, audio_file, target_seconds=180):
        try:
            signal, sample_rate = librosa.load(audio_file, sr=None)
            if len(signal) >= 2048:
                features = {}
                
                # MFCC features
                mfcc_stats = self.extract_mfcc_statistics(signal, sample_rate)
                features.update({f'{key}': value for key, value in mfcc_stats.items()})

                # ZCR features
                zcr_stats = self.extract_zcr_statistics(signal, frame_size=2048, hop_size=512)
                features.update({f'zcr_{key}': value for key, value in zcr_stats.items()})

                # Pitch features
                pitch_stats = self.extract_pitch_statistics(signal, sample_rate)
                features.update({f'pitch_{key}': value for key, value in pitch_stats.items()})

                # RMS features
                rms_stats = self.extract_rms_statistics(signal, frame_size=2048, hop_size=512)
                features.update({f'rms_{key}': value for key, value in rms_stats.items()})

                return features
            
        except Exception as e:
            logger.error(f"Error processing file {audio_file}: {e}")
        return None

    def process_folder(self, input_folder, csv_file):
      file_and_label_df = pd.read_csv(csv_file)
      feature_dataframes = pd.DataFrame()  # DataFrame để lưu trữ các features từ tất cả các file âm thanh

      for index, row in file_and_label_df.iterrows():
          file_path = row['cleaned_file_path']
          label = row['label']
          features = self.feature_engineering_for_file(file_path)

          if index % 100 == 0:
              logger.info(f'Processed {index} file!')
              feature_dataframes.to_csv('validation_feature_data.csv', index=False)

          if features is not None:
              features['file_path'] = file_path
              features['label'] = label
              feature_dataframe = pd.DataFrame([features])  # Tạo DataFrame từ features của mỗi file
              feature_dataframes = pd.concat([feature_dataframes, feature_dataframe], ignore_index=True)  # Kết hợp DataFrame mới vào DataFrame tổng hợp

      # Lưu DataFrame tổng hợp vào tệp CSV
      feature_dataframes.to_csv('validation_feature_data.csv', index=False)


feature_extractor = StatisticFeatureExtraction()
feature_extractor.process_folder(r'D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation', r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation_file_paths_with_labels.csv")
# Out:
# 2024-05-29 16:30:10.590 | INFO     | __main__:process_folder:99 - Processed 0 file!
# 2024-05-29 16:31:03.378 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1001_ITH_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:31:04.487 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1001_ITH_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:31:05.265 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1001_ITH_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:31:09.431 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1001_WSI_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:31:10.837 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1001_WSI_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:31:12.254 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1001_WSI_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:31:47.875 | INFO     | __main__:process_folder:99 - Processed 100 file!
# 2024-05-29 16:31:53.255 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1015_ITH_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:32:38.827 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1031_ITH_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:33:00.649 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1034_TSI_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:33:01.583 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1034_TSI_ANG_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:33:13.048 | INFO     | __main__:process_folder:99 - Processed 200 file!
# 2024-05-29 16:34:36.278 | INFO     | __main__:process_folder:99 - Processed 300 file!
# 2024-05-29 16:36:02.322 | INFO     | __main__:process_folder:99 - Processed 400 file!
# 2024-05-29 16:37:26.467 | INFO     | __main__:process_folder:99 - Processed 500 file!
# 2024-05-29 16:39:05.701 | INFO     | __main__:process_folder:99 - Processed 600 file!
# 2024-05-29 16:40:14.416 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1007_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:40:15.701 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1007_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:40:51.814 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1015_IWW_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:40:56.309 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1017_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:40:56.964 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1017_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:40:57.607 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1017_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:41:04.372 | INFO     | __main__:process_folder:99 - Processed 700 file!
# 2024-05-29 16:41:11.805 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1020_IWW_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:18.742 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1030_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:19.857 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1030_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:21.019 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1030_DFA_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:39.344 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1035_ITH_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:40.347 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1035_ITH_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:41.482 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1035_ITH_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:46.043 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1035_WSI_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:42:51.947 | INFO     | __main__:process_folder:99 - Processed 800 file!
# 2024-05-29 16:43:45.539 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1045_IWL_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:43:46.979 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1045_IWL_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:43:48.285 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1045_IWL_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:08.236 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1048_TSI_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:09.699 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1048_TSI_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:11.169 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1048_TSI_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:16.047 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1051_ITH_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:17.569 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1051_ITH_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:19.156 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1051_ITH_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:20.455 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1051_IWW_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:21.785 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1051_IWW_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:23.125 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1051_IWW_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:44:48.165 | INFO     | __main__:process_folder:99 - Processed 900 file!
# 2024-05-29 16:45:32.103 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1075_TIE_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:45:33.609 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1075_TIE_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:45:34.999 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1075_TIE_DIS_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:46:38.374 | INFO     | __main__:process_folder:99 - Processed 1000 file!
# 2024-05-29 16:48:22.256 | INFO     | __main__:process_folder:99 - Processed 1100 file!
# 2024-05-29 16:49:55.674 | INFO     | __main__:process_folder:99 - Processed 1200 file!
# 2024-05-29 16:51:28.815 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1028_IEO_FEA_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:51:29.779 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1028_IEO_FEA_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:51:30.776 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1028_IEO_FEA_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:51:37.390 | INFO     | __main__:process_folder:99 - Processed 1300 file!
# 2024-05-29 16:53:06.868 | INFO     | __main__:process_folder:99 - Processed 1400 file!
# 2024-05-29 16:53:08.203 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1048_TSI_FEA_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:53:09.370 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1048_TSI_FEA_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:53:10.375 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1048_TSI_FEA_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:54:35.573 | INFO     | __main__:process_folder:99 - Processed 1500 file!
# 2024-05-29 16:56:07.547 | INFO     | __main__:process_folder:99 - Processed 1600 file!
# 2024-05-29 16:57:20.851 | INFO     | __main__:process_folder:99 - Processed 1700 file!
# 2024-05-29 16:57:56.990 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1001_ITS_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:57:57.558 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1001_ITS_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:57:58.505 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1001_ITS_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:58:09.966 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1002_ITS_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:58:10.967 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1002_ITS_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:58:12.042 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1002_ITS_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:58:16.316 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1002_TSI_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:58:48.413 | INFO     | __main__:process_folder:99 - Processed 1800 file!
# 2024-05-29 16:59:17.703 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1016_IEO_HAP_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:59:18.669 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1016_IEO_HAP_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:59:20.606 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1016_TSI_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:59:21.565 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1016_TSI_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:59:22.568 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1016_TSI_HAP_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 16:59:39.062 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1022_IEO_HAP_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:00:13.910 | INFO     | __main__:process_folder:99 - Processed 1900 file!
# 2024-05-29 17:01:37.398 | INFO     | __main__:process_folder:99 - Processed 2000 file!
# 2024-05-29 17:02:24.651 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1063_IEO_HAP_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:03:00.478 | INFO     | __main__:process_folder:99 - Processed 2100 file!
# 2024-05-29 17:04:26.653 | INFO     | __main__:process_folder:99 - Processed 2200 file!
# 2024-05-29 17:05:47.288 | INFO     | __main__:process_folder:99 - Processed 2300 file!
# 2024-05-29 17:07:17.773 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1030_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:07:18.698 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1030_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:07:19.829 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1030_DFA_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:07:31.792 | INFO     | __main__:process_folder:99 - Processed 2400 file!
# 2024-05-29 17:09:06.552 | INFO     | __main__:process_folder:99 - Processed 2500 file!
# 2024-05-29 17:09:08.628 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1054_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:09:09.403 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1054_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:09:10.108 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1054_TSI_NEU_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:10:46.490 | INFO     | __main__:process_folder:99 - Processed 2600 file!
# 2024-05-29 17:12:30.617 | INFO     | __main__:process_folder:99 - Processed 2700 file!
# 2024-05-29 17:14:00.262 | INFO     | __main__:process_folder:99 - Processed 2800 file!
# 2024-05-29 17:14:08.646 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1001_ITH_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:09.752 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1001_ITH_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:10.831 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1001_ITH_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:15.787 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1002_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:16.935 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1002_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:18.047 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1002_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:22.916 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1006_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:23.905 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1006_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:24.733 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1006_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:31.290 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1009_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:32.497 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1009_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:33.692 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1009_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:48.807 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1014_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:49.731 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1014_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:50.597 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1014_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:57.396 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1015_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:58.373 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1015_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:14:59.401 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1015_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:00.342 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1018_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:01.274 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1018_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:02.145 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1018_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:22.141 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1021_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:23.672 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1021_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:28.644 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1022_IEO_SAD_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:29.792 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1022_IEO_SAD_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:30.992 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1022_IEO_SAD_MD.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:45.017 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1024_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:45.945 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1024_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:46.562 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1024_IEO_SAD_HI.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:15:56.729 | INFO     | __main__:process_folder:99 - Processed 2900 file!
# 2024-05-29 17:16:21.519 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1034_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:16:22.573 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1034_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:16:23.559 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1034_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:16:58.898 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1041_DFA_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:16:59.903 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1041_DFA_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:17:00.988 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1041_DFA_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:17:44.090 | INFO     | __main__:process_folder:99 - Processed 3000 file!
# 2024-05-29 17:18:00.729 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1059_ITH_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:18:34.804 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1065_IEO_SAD_LO.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:18:40.708 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1065_MTI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:18:42.966 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1065_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:18:44.239 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1065_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:18:45.696 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1065_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:01.819 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1068_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:03.030 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1068_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:04.127 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1068_TSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:14.525 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1071_TIE_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:32.349 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1075_IWL_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:33.563 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1075_IWL_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:34.767 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1075_IWL_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:35.901 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1075_TAI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:37.017 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1075_TAI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:19:37.017 | INFO     | __main__:process_folder:99 - Processed 3100 file!
# 2024-05-29 17:19:38.688 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1075_TAI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:20:19.479 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\1086_WSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:20:20.236 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_1086_WSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:20:20.918 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\time_shift_1086_WSI_SAD_XX.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:21:09.785 | INFO     | __main__:process_folder:99 - Processed 3200 file!
# 2024-05-29 17:22:38.635 | INFO     | __main__:process_folder:99 - Processed 3300 file!
# 2024-05-29 17:23:28.868 | ERROR    | __main__:feature_engineering_for_file:86 - Error processing file D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation\noisy_03-01-08-02-02-01-19.wav: 'tuple' object has no attribute 'items'
# 2024-05-29 17:23:47.839 | INFO     | __main__:process_folder:99 - Processed 3400 file!
# 2024-05-29 17:24:57.979 | INFO     | __main__:process_folder:99 - Processed 3500 file!

# %%
from loguru import logger
import os
import librosa
import csv
import pandas as pd
import numpy as np
from scripts.mfcc_extractor import MfccExtractor
from scripts.pitch_extractor import PitchExtractor
from scripts.rms_extractor import RmsExtractor
from scripts.zcr_extractor import ZcrExtractor

class FeatureExtractor:
    def __init__(self, n_mfcc=20):
        self.n_mfcc = n_mfcc

    def extract_original_mfcc(self, signal, sample_rate, frame_size, hop_size):
        mfcc_extractor = MfccExtractor(signal, sample_rate, self.n_mfcc, frame_size, hop_size)
        mfcc_matrix = mfcc_extractor.compute_mfccs()
        mfcc_vectors = []
        for row in range(mfcc_matrix.shape[0]):
            mfcc_vector = mfcc_matrix[row, :]
            mfcc_vectors.append(mfcc_vector)

        return mfcc_vectors
    
    def extract_pitch(self, signal, sample_rate, frame_size, hop_size):
        pitch_extractor = PitchExtractor(signal, sample_rate, frame_size, hop_size)
        return pitch_extractor.compute_pitch()
    
    def extract_original_zcr(self, signal, frame_size, hop_size):
        zcr_extractor = ZcrExtractor(signal, frame_size, hop_size)
        zcr = zcr_extractor.compute_zcr()
        return zcr
    
    def extract_original_rms(self, signal, frame_size, hop_size):
        rms_extractor = RmsExtractor(signal, frame_size, hop_size)
        return rms_extractor.compute_rms()
    
    def pad_or_trim(self, zcr, target_length):
      if len(zcr) < target_length:
          return np.pad(zcr, (0, target_length - len(zcr)), 'constant')
      else:
          return zcr[:target_length]
    
    def calculate_number_of_frames(self, audio_length, sample_rate, frame_length, hop_length):
      """
      Tính số lượng khung dựa vào độ dài tín hiệu âm thanh, tần số lấy mẫu, frame length, và hop length.
      """
      # Tính độ dài tín hiệu âm thanh bằng số mẫu
      signal_length = int(audio_length * sample_rate)
      
      # Tính số lượng khung
      num_frames = 1 + (signal_length - frame_length) // hop_length
      
      return num_frames

    def feature_engineering_for_file(self, audio_file, target_seconds=3, frame_size=2048, hop_size=512):
        try:
            signal, sample_rate = librosa.load(audio_file, sr=None)
            if len(signal) >= frame_size:
                zcr = self.extract_original_zcr(signal, frame_size, hop_size)
                num_of_frames = self.calculate_number_of_frames(target_seconds, sample_rate, frame_size, hop_size)
                zcr_normalize = self.pad_or_trim(zcr, num_of_frames)

                rms = self.extract_original_rms(signal, frame_size, hop_size)
                rms_normalize = self.pad_or_trim(rms, num_of_frames)

                pitch = self.extract_pitch(signal, sample_rate, frame_size, hop_size)
                pitch_normalize = self.pad_or_trim(pitch, num_of_frames)

                mfcc_normalize = []
                for mfcc_vector in self.extract_original_mfcc(signal, sample_rate, frame_size, hop_size):
                    normalized_mfcc_vector = self.pad_or_trim(mfcc_vector, num_of_frames)
                    mfcc_normalize.append(normalized_mfcc_vector)
                
                stacked_mfcc = np.hstack(mfcc_normalize)

                combined_features = np.hstack((zcr_normalize, rms_normalize, pitch_normalize, stacked_mfcc))
                return combined_features
        except Exception as e:
            logger.error(f"Error processing file {audio_file}: {e}")
        return None

    def process_folder(self, input_folder, csv_file):
        file_and_label_df = pd.read_csv(csv_file)
        feature_dataframes = pd.DataFrame()  # DataFrame to store features from all audio files

        for index, row in file_and_label_df.iterrows():
            file_path = row['cleaned_file_path']
            label = row['label']
            features = self.feature_engineering_for_file(file_path)

            if index % 100 == 0:
                logger.info(f'Processed {index} file!')
                feature_dataframes.to_csv('_val_feature_data.csv', index=False)

            if features is not None:
                features_dict = {
                    'file_path': file_path,
                    'label': label
                }
                for i, feature in enumerate(features):
                    features_dict[f'feature_{i+1}'] = feature  # Assign feature values to corresponding columns in DataFrame
                feature_dataframe = pd.DataFrame([features_dict])  # Convert the dictionary to a DataFrame
                feature_dataframes = pd.concat([feature_dataframes, feature_dataframe], ignore_index=True)  # Append the new row to the aggregated DataFrame

        # Save the aggregated DataFrame to a CSV file
        feature_dataframes.to_csv('_val_feature_data.csv', index=False)

# %%
feature_extractor = FeatureExtractor()
feature_extractor.process_folder(r'D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation', r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned_data\validation_file_paths_with_labels.csv")
# Out:
# 2024-05-31 08:18:14.973 | INFO     | __main__:process_folder:94 - Processed 0 file!
# 2024-05-31 08:19:17.422 | INFO     | __main__:process_folder:94 - Processed 100 file!
# 2024-05-31 08:20:31.889 | INFO     | __main__:process_folder:94 - Processed 200 file!
# 2024-05-31 08:21:30.669 | INFO     | __main__:process_folder:94 - Processed 300 file!
# 2024-05-31 08:22:30.655 | INFO     | __main__:process_folder:94 - Processed 400 file!
# 2024-05-31 08:23:23.522 | INFO     | __main__:process_folder:94 - Processed 500 file!
# 2024-05-31 08:24:21.454 | INFO     | __main__:process_folder:94 - Processed 600 file!
# 2024-05-31 08:25:49.000 | INFO     | __main__:process_folder:94 - Processed 700 file!
# 2024-05-31 08:27:13.147 | INFO     | __main__:process_folder:94 - Processed 800 file!
# 2024-05-31 08:28:46.034 | INFO     | __main__:process_folder:94 - Processed 900 file!
# 2024-05-31 08:30:22.481 | INFO     | __main__:process_folder:94 - Processed 1000 file!
# 2024-05-31 08:31:48.442 | INFO     | __main__:process_folder:94 - Processed 1100 file!
# 2024-05-31 08:32:51.826 | INFO     | __main__:process_folder:94 - Processed 1200 file!
# 2024-05-31 08:34:09.036 | INFO     | __main__:process_folder:94 - Processed 1300 file!
# 2024-05-31 08:35:08.763 | INFO     | __main__:process_folder:94 - Processed 1400 file!
# 2024-05-31 08:36:13.531 | INFO     | __main__:process_folder:94 - Processed 1500 file!
# 2024-05-31 08:37:09.929 | INFO     | __main__:process_folder:94 - Processed 1600 file!
# 2024-05-31 08:37:55.933 | INFO     | __main__:process_folder:94 - Processed 1700 file!
# 2024-05-31 08:38:54.913 | INFO     | __main__:process_folder:94 - Processed 1800 file!
# 2024-05-31 08:40:05.095 | INFO     | __main__:process_folder:94 - Processed 1900 file!
# 2024-05-31 08:41:07.087 | INFO     | __main__:process_folder:94 - Processed 2000 file!
# 2024-05-31 08:42:10.573 | INFO     | __main__:process_folder:94 - Processed 2100 file!
# 2024-05-31 08:43:12.510 | INFO     | __main__:process_folder:94 - Processed 2200 file!
# 2024-05-31 08:44:06.124 | INFO     | __main__:process_folder:94 - Processed 2300 file!
# 2024-05-31 08:45:17.809 | INFO     | __main__:process_folder:94 - Processed 2400 file!
# 2024-05-31 08:46:20.586 | INFO     | __main__:process_folder:94 - Processed 2500 file!
# 2024-05-31 08:48:35.703 | INFO     | __main__:process_folder:94 - Processed 2600 file!
# 2024-05-31 08:49:47.907 | INFO     | __main__:process_folder:94 - Processed 2700 file!
# 2024-05-31 08:50:47.500 | INFO     | __main__:process_folder:94 - Processed 2800 file!
# 2024-05-31 08:52:25.843 | INFO     | __main__:process_folder:94 - Processed 2900 file!
# 2024-05-31 08:53:58.173 | INFO     | __main__:process_folder:94 - Processed 3000 file!
# 2024-05-31 08:55:03.011 | INFO     | __main__:process_folder:94 - Processed 3100 file!
# 2024-05-31 08:56:05.909 | INFO     | __main__:process_folder:94 - Processed 3200 file!
# 2024-05-31 08:57:10.933 | INFO     | __main__:process_folder:94 - Processed 3300 file!
# 2024-05-31 08:58:03.557 | INFO     | __main__:process_folder:94 - Processed 3400 file!
# 2024-05-31 08:58:58.025 | INFO     | __main__:process_folder:94 - Processed 3500 file!
