# %%
from training_models.best_random_forest_model import ModelTester
from config.eng_config import Config

# %%
config = Config()

# %%
tester = ModelTester(config, n_mfcc=13)
best_pipeline = tester.find_best_pipeline()
print("Best Pipeline:")
print(best_pipeline)
# Out:
# 2024-06-06 20:00:57.353 | INFO     | training_models.best_random_forest_model:find_best_pipeline:83 - Testing pipeline with features: ['mfcc', 'zcr', 'rms', 'pitch'], statistics: ['mean', 'variance', 'max', 'min', 'median', '25th_percentile', '75th_percentile']
# 2024-06-06 20:01:23.456 | DEBUG    | training_models.best_random_forest_model:test_models:67 - Best accuracy: 0.6304541406945681, Best pipeline: {'model': 'RandomForestClassifier', 'accuracy': 0.6304541406945681, 'pipeline_details': {'features': ['mfcc', 'zcr', 'rms', 'pitch'], 'statistics': ['mean', 'variance', 'max', 'min', 'median', '25th_percentile', '75th_percentile']}}
# 2024-06-06 20:01:28.615 | INFO     | training_models.best_random_forest_model:find_best_pipeline:83 - Testing pipeline with features: ['mfcc', 'zcr', 'rms', 'pitch'], statistics: ['variance', 'max', 'min', 'median', '25th_percentile', '75th_percentile']
# ...

# %%
tester = ModelTester(config, n_mfcc=20)
best_pipeline = tester.find_best_pipeline()
print("Best Pipeline:")
print(best_pipeline)
# Out:
# 2024-06-06 22:12:46.220 | INFO     | training_models.best_random_forest_model:find_best_pipeline:83 - Testing pipeline with features: ['mfcc', 'zcr', 'rms', 'pitch'], statistics: ['mean', 'variance', 'max', 'min', 'median', '25th_percentile', '75th_percentile']
# 2024-06-06 22:13:16.457 | DEBUG    | training_models.best_random_forest_model:test_models:67 - Best accuracy: 0.6248144850103888, Best pipeline: {'model': 'RandomForestClassifier', 'accuracy': 0.6248144850103888, 'pipeline_details': {'features': ['mfcc', 'zcr', 'rms', 'pitch'], 'statistics': ['mean', 'variance', 'max', 'min', 'median', '25th_percentile', '75th_percentile']}}
# ...

# %%
tester = ModelTester(config, n_mfcc=26)
best_pipeline = tester.find_best_pipeline()
print("Best Pipeline:")
print(best_pipeline)
