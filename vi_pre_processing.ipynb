# %%
from config.vi_config import VietnameseDatasetConfig
from src.data_preparation_runner import DataPreparationRunner
from src.data_preprocessing_runner import DataPreprocessingRunner
from src.feature_extraction_runner import FeatureExtractionRunner
from src.mel_spectrogram_extraction_runner import MelSpectrogramExtractionRunner

# %%
config = VietnameseDatasetConfig()
data_preparation_runner = DataPreparationRunner(config)
data_preparation_runner.run()

# %%
data_preeprocessing_runner = DataPreprocessingRunner(config)
data_preeprocessing_runner.run()

# %%
feature_extraction_runner = FeatureExtractionRunner(config)
feature_extraction_runner.run()
# Out:
# Running feature extraction for train dataset...
# 2024-06-07 13:55:32.730 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 0 file.
# 2024-06-07 13:56:22.111 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 100 file.
# 2024-06-07 13:57:19.027 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 200 file.
# 2024-06-07 13:58:11.629 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 300 file.
# 2024-06-07 13:59:00.702 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 400 file.
# 2024-06-07 13:59:43.540 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 500 file.
# ...

# %%
feature_extraction_runner = FeatureExtractionRunner(config)
feature_extraction_runner.run()
# Out:
# Running feature extraction for train dataset...
# 2024-06-07 13:55:32.730 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 0 file.
# 2024-06-07 13:56:22.111 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 100 file.
# 2024-06-07 13:57:19.027 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 200 file.
# 2024-06-07 13:58:11.629 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 300 file.
# 2024-06-07 13:59:00.702 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 400 file.
# 2024-06-07 13:59:43.540 | INFO     | modules.feature_extraction.scripts.extract_statistic_features:process_folder:165 - Processed 500 file.
# ...

# %%
mel_spectrogram_extraction_runner = MelSpectrogramExtractionRunner(config)
mel_spectrogram_extraction_runner.run()
# Out:
# 2024-06-07 14:08:26.823 | INFO     | modules.feature_extraction.scripts.extract_mel_spectrogram:process_folder:58 - Processed 0 files!
# Extracting Mel spectrogram for train dataset...
# 2024-06-07 14:08:27.323 | INFO     | modules.feature_extraction.scripts.extract_mel_spectrogram:process_folder:58 - Processed 1 files!
# 2024-06-07 14:08:27.378 | INFO     | modules.feature_extraction.scripts.extract_mel_spectrogram:process_folder:58 - Processed 2 files!
# 2024-06-07 14:08:27.432 | INFO     | modules.feature_extraction.scripts.extract_mel_spectrogram:process_folder:58 - Processed 3 files!
# 2024-06-07 14:08:27.485 | INFO     | modules.feature_extraction.scripts.extract_mel_spectrogram:process_folder:58 - Processed 4 files!
# 2024-06-07 14:08:27.540 | INFO     | modules.feature_extraction.scripts.extract_mel_spectrogram:process_folder:58 - Processed 5 files!
# ...
