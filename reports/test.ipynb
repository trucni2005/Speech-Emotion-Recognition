# %%
import matplotlib.pyplot as plt
import librosa
import librosa.display
import numpy as np

# %%
def plot_audio(file_path):
    # Đọc file âm thanh và tần số lấy mẫu
    y, sr = librosa.load(file_path, sr=None)

    # Biểu đồ âm thanh theo thời gian
    plt.figure(figsize=(12, 8))
    
    # Biểu đồ dạng sóng
    plt.subplot(3, 1, 1)
    librosa.display.waveshow(y, sr=sr)
    plt.title('Waveform of Audio File')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    # Biểu đồ phổ âm thanh (Spectrogram)
    plt.subplot(3, 1, 2)
    D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
    librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
    plt.colorbar(format='%+2.0f dB')
    plt.title('Spectrogram of Audio File')
    plt.xlabel('Time (s)')
    plt.ylabel('Frequency (Hz)')

    # Trích xuất và biểu diễn Mel Spectrogram
    plt.subplot(3, 1, 3)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
    S_dB = librosa.amplitude_to_db(S, ref=np.max)
    librosa.display.specshow(S_dB, sr=sr, x_axis='time', y_axis='mel', fmax=8000)
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel Spectrogram of Audio File')
    plt.xlabel('Time (s)')
    plt.ylabel('Mel Frequency')

    plt.tight_layout()
    plt.show()

# %%
file_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\augmented\train\03-01-01-01-01-01-01.wav"
plot_audio(file_path)

# %%
file_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\augmented\train\noisy_03-01-01-01-01-01-01.wav"
plot_audio(file_path)

# %%
file_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\augmented\train\time_shift_03-01-01-01-01-01-01.wav"
plot_audio(file_path)

# %%
file_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned\train\03-01-01-01-01-01-01.wav"
plot_audio(file_path)

# %%
file_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned\train\noisy_03-01-01-01-01-01-01.wav"
plot_audio(file_path)

# %%
file_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\cleaned\train\time_shift_03-01-01-01-01-01-01.wav"
plot_audio(file_path)
