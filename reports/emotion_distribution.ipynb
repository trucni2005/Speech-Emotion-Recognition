# %%
from scripts.emotion_distribution import plot_emotion_distribution, count_samples_in_subfolders, plot_sample_distribution, count_samples_per_label, plot_sample_distribution_table

# %%
base_folder = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\raw"
emotions, train_counts, validation_counts, test_counts = count_samples_in_subfolders(base_folder)
plot_sample_distribution(emotions, train_counts, validation_counts, test_counts)

# %%
base_folder = r"D:\data_analysis\speech_emotion_recognition\data\VietnameseDataset\train_test_splited_data\raw"
emotions, train_counts, validation_counts, test_counts = count_samples_in_subfolders(base_folder)
plot_sample_distribution(emotions, train_counts, validation_counts, test_counts)

# %%
base_folder = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\train_test_splited_data\augmented"
sample_counts = count_samples_per_label(base_folder)
plot_sample_distribution_table(sample_counts)

# %%
base_folder = r"D:\data_analysis\speech_emotion_recognition\data\VietnameseDataset\train_test_splited_data\augmented"
sample_counts = count_samples_per_label(base_folder)
plot_sample_distribution_table(sample_counts)

# %% [markdown]
# # Dữ liệu tiếng Anh sau khi gộp từ 4 bộ dữ liệu: TESS, SAVEE, RAVDESS và CREMA-D

# %%
folder_path = r"D:\data_analysis\speech_emotion_recognition\data\EnglishDataset\combined_data"
plot_emotion_distribution(folder_path)

# %% [markdown]
# # Dữ liệu tiếng Anh sau khi chia thành 3 phần: Train, Test và Validation

# %% [markdown]
# **Dữ liệu tập train sau khi chia thành các tập dữ liệu**

# %%
folder_path = r"D:\data_analysis\speech_emotion_recognition\data\VietnameseDataset\raw"
plot_emotion_distribution(folder_path)
